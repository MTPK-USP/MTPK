# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#P0_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P0_FKP.dat')
P0_MT = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P0_MTOE.dat')

#P2_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P2_FKP.dat')
P2_MT = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P2_MTOE.dat')

#P4_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P4_FKP.dat')
P4_MT = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_P4_MTOE.dat')

#C0_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_C0_FKP.dat')
#C2_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_C2_FKP.dat')
#C4_FKP = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_C4_FKP.dat')

k = np.loadtxt('spectra/ExSHalos/k=0.1/ExSHalos_vec_k.dat')

# %%
#P0_FKP.shape, #P0_MT.shape, P2_FKP.shape, P2_MT.shape, #C0_FKP.shape, C2_FKP.shape, C4_FKP.shape, k.shape

# %%
# P_0_FKP = np.zeros( ( 3, k.shape[0] ) )
# P_2_FKP = np.zeros( ( 3, k.shape[0] ) )
# P_4_FKP = np.zeros( ( 3, k.shape[0] ) )

P_0_MT = np.zeros( ( 3, k.shape[0] ) )
P_2_MT = np.zeros( ( 3, k.shape[0] ) )
P_4_MT = np.zeros( ( 3, k.shape[0] ) )

# C_0_FKP = np.zeros( ( 3, k.shape[0] ) )
# C_2_FKP = np.zeros( ( 3, k.shape[0] ) )
# C_4_FKP = np.zeros( ( 3, k.shape[0] ) )

# %%
for i in range(3):
    for j in range(k.shape[0]):
#         P_0_FKP[i] = P0_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]
#         P_2_FKP[i] = P2_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]
#         P_4_FKP[i] = P4_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]
        
        P_0_MT[i] = P0_MT[i, k.shape[0]*i:k.shape[0]*(i + 1)]
        P_2_MT[i] = P2_MT[i, k.shape[0]*i:k.shape[0]*(i + 1)]
        P_4_MT[i] = P4_MT[i, k.shape[0]*i:k.shape[0]*(i + 1)]
        
#         C_0_FKP[i] = C0_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]
#         C_2_FKP[i] = C2_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]
#         C_4_FKP[i] = C4_FKP[i, k.shape[0]*i:k.shape[0]*(i + 1)]

# %%
plt.figure(dpi = 100)
# plt.loglog(k, np.mean(P_0_FKP, axis = 0), label = 'FKP Monopole')
# plt.loglog(k, np.mean(P_2_FKP, axis = 0), label = 'FKP Dipole')
# plt.loglog(k, np.mean(P_4_FKP, axis = 0), label = 'FKP Quadrupole')

plt.loglog(k, np.mean(P_0_MT, axis = 0), '--', label = 'MT Monopole')
plt.loglog(k, np.mean(P_2_MT, axis = 0), '--', label = 'MT Dipole')
plt.loglog(k, np.mean(P_4_MT, axis = 0), '--', label = 'MT Quadrupole')

plt.legend()

# %%
plt.figure(dpi = 100)
plt.loglog(k, np.mean(C_0_FKP, axis = 0), label = 'C0')
plt.loglog(k, np.mean(C_2_FKP, axis = 0), label = 'C2')
plt.loglog(k, np.mean(C_4_FKP, axis = 0), label = 'C4')
plt.legend()
